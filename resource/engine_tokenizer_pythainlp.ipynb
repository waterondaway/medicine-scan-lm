# %% [markdown]
# ## Comparative Engine of Tokenizer from PythaiNLP 💻

# %%
# PythaiNLP - Tokenizer Download From Library
from pythainlp.tokenize import word_tokenize as pythainlp_tokenizer

# %%
# Setup default string data
default_text = """
ชื่อ อรจิรา พงศ์ฉบับนภา
บัตรประจำตัว 5556060008170
วันเกิด 29 มิถุนายน 2515
REG006
วันผลิต 2024-07-30
วันหมดอายุ 2026-02-05
DOXYCYCLINE 500mg CAPSULE
รับประทาน 2 เม็ดก่อนนอน
บรรเทาอาการปวดเบา
ห้ามใช้ในหญิงตั้งครรภ์
"""

# %%
# Clean & Display string data - remove new lines syntax in string
cleaned_text = default_text.replace('\n', " ")
print(cleaned_text)
# Out:
#  ชื่อ อรจิรา พงศ์ฉบับนภา บัตรประจำตัว 5556060008170 วันเกิด 29 มิถุนายน 2515 REG006 วันผลิต 2024-07-30 วันหมดอายุ 2026-02-05 DOXYCYCLINE 500mg CAPSULE รับประทาน 2 เม็ดก่อนนอน บรรเทาอาการปวดเบา ห้ามใช้ในหญิงตั้งครรภ์

# %%
# Engine: newmm (default)
newmm_tokens = pythainlp_tokenizer(cleaned_text, engine='newmm')
print(newmm_tokens)
print(f'Number of tokens: {len(newmm_tokens)}')
# Out:
# [' ', 'ชื่อ', ' ', 'อร', 'จิ', 'รา', ' ', 'พงศ์', 'ฉบับ', 'นภา', ' ', 'บัตรประจำตัว', ' ', '5556060008170', ' ', 'วันเกิด', ' ', '29', ' ', 'มิถุนายน', ' ', '2515', ' ', 'REG', '006', ' ', 'วัน', 'ผลิต', ' ', '2024', '-', '07', '-', '30', ' ', 'วันหมดอายุ', ' ', '2026', '-', '02', '-', '05', ' ', 'DOXYCYCLINE', ' ', '500', 'mg', ' ', 'CAPSULE', ' ', 'รับประทาน', ' ', '2', ' ', 'เม็ด', 'ก่อน', 'นอน', ' ', 'บรรเทา', 'อาการ', 'ปวด', 'เบา', ' ', 'ห้าม', 'ใช้', 'ใน', 'หญิง', 'ตั้งครรภ์', ' ']
# Number of tokens: 69

# %%
# Engine: longest
longest_tokens = pythainlp_tokenizer(cleaned_text, engine='longest')
print(longest_tokens)
print(f'Number of tokens: {len(longest_tokens)}')
# Out:
# [' ', 'ชื่อ', ' ', 'อร', 'จิ', 'รา', ' ', 'พงศ์', 'ฉบับ', 'นภา', ' ', 'บัตรประจำตัว', ' ', '5556060008170', ' ', 'วันเกิด', ' ', '29', ' ', 'มิถุนายน', ' ', '2515', ' ', 'reg006', ' ', 'วัน', 'ผลิต', ' ', '2024', '-', '07', '-', '30', ' ', 'วันหมดอายุ', ' ', '2026', '-', '02', '-', '05', ' ', 'doxycycline', ' ', '500mg', ' ', 'capsule', ' ', 'รับประทาน', ' ', '2', ' ', 'เม็ด', 'ก่อน', 'นอน', ' ', 'บรรเทา', 'อาการ', 'ปวด', 'เบา', ' ', 'ห้าม', 'ใช้', 'ใน', 'หญิง', 'ตั้งครรภ์', ' ']
# Number of tokens: 67

# %%
# Engine: attacut
attacut_tokens = pythainlp_tokenizer(cleaned_text, engine='attacut')
print(attacut_tokens)
print(f'Number of tokens: {len(attacut_tokens)}')
# Out:
# [' ', 'ชื่อ', ' ', 'อรจิรา พงศ์', 'ฉบับนภา', ' ', 'บัตร', 'ประจำ', 'ตัว', ' ', '5556060008170', ' ', 'วัน', 'เกิด', ' ', '29', ' ', 'มิถุนายน', ' ', '2515', ' ', 'REG006', ' ', 'วัน', 'ผลิต', ' ', '2024', '-', '07', '-', '30', ' ', 'วัน', 'หมด', 'อายุ', ' ', '2026', '-', '02', '-', '05', ' ', 'DOXYCYCLINE 500mg', ' ', 'CAPSULE', ' ', 'รับประทาน', ' ', '2', ' ', 'เม็ด', 'ก่อน', 'นอน', ' ', 'บรรเทา', 'อาการ', 'ปวด', 'เบา', ' ', 'ห้าม', 'ใช้', 'ใน', 'หญิง', 'ตั้ง', 'ครรภ์', ' ']
# Number of tokens: 66
