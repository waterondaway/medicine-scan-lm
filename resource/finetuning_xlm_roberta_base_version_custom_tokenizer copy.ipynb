# %% [markdown]
# ## Fine-Tuning Language Model 💻

# %%
# Setup Labels for Download XLM Roberta Base
labels_to_id = {
    "O": 0,
    "B-DRUG_NAME": 1, "I-DRUG_NAME": 2,
    "B-DOSAGE": 3, "I-DOSAGE": 4,
    "B-FORM": 5, "I-FORM": 6,
    "B-WARNINGS": 7, "I-WARNINGS": 8,
    "B-INDICATIONS": 9, "I-INDICATIONS": 10,
    "B-USAGE_INSTRUCTIONS": 11, "I-USAGE_INSTRUCTIONS": 12
}
id_to_labels = {v: k for k, v in labels_to_id.items()}

# %%
# XLM Roberta Base - Pretrained Model Download From HuggingFace
from transformers import XLMRobertaForTokenClassification
xlm_roberta_model = XLMRobertaForTokenClassification.from_pretrained("xlm-roberta-base", num_labels=len(labels_to_id), id2label=id_to_labels, label2id=labels_to_id)
# Out:
# Some weights of XLMRobertaForTokenClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Custom Tokenizer - Tokenizer Download From HuggingFace
from transformers import XLMRobertaTokenizer
custom_tokenizer = XLMRobertaTokenizer.from_pretrained("../tokenizer")

# %%
# Resize Embeddings of Model
xlm_roberta_model.resize_token_embeddings(len(custom_tokenizer))
# Out:
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Embedding(250063, 768, padding_idx=1)

# %%
# Import Custom Tokenizer Dataset to fine-tuning
import json
with open('../data/custom_tokenizer_format.json', 'r', encoding='utf-8') as f:
    custom_tokenizer_dataset = json.load(f)

# %%
# Mapping dataset
from datasets import Dataset
custom_tokenizer_dataset = Dataset.from_dict({
    "tokens": [item["tokens"] for item in custom_tokenizer_dataset],
    "labels": [item["ner_tags"] for item in custom_tokenizer_dataset]
})
print(custom_tokenizer_dataset)
# Out:
# Dataset({
#     features: ['tokens', 'labels'],
#     num_rows: 2000
# })

# %%
# Function to align dataset
def tokenize_and_align_labels(examples):
    tokenized_inputs = custom_tokenizer(examples['tokens'], padding="longest", truncation=True, return_tensors="pt", is_split_into_words=True)
    aligned_labels = []
    for i, labels in enumerate(examples['labels']):
        label_ids = [labels_to_id[label] for label in labels]
        padding_length = len(tokenized_inputs['input_ids'][i]) - len(label_ids)
        label_ids += [-100] * padding_length
        aligned_labels.append(label_ids)
        
    tokenized_inputs['labels'] = aligned_labels
    return tokenized_inputs

# %%
# Align labels of Custom Tokenizer Dataset
custom_tokenized_dataset = custom_tokenizer_dataset.map(tokenize_and_align_labels, batched=True)
# Out:
# Map: 100%|██████████| 2000/2000 [00:00<00:00, 2418.98 examples/s]

# %%
# Display number of XLM Roberta Base - Tokenizer Dataset
print(custom_tokenized_dataset)
# Out:
# Dataset({
#     features: ['tokens', 'labels', 'input_ids', 'attention_mask'],
#     num_rows: 2000
# })

# %%
# Setup Traning Arguments
train_dataset = custom_tokenized_dataset.select(range(0, 800))
eval_dataset = custom_tokenized_dataset.select(range(800, 1000))

from transformers import Trainer, TrainingArguments
training_arguments = TrainingArguments(
    output_dir='../output/model/custom_tokenizer',         
    num_train_epochs=10,            
    per_device_train_batch_size=4,   
    per_device_eval_batch_size=4, 
    warmup_ratio=0.1,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=100,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True
)
trainer = Trainer(
    model=xlm_roberta_model, 
    args=training_arguments, 
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    tokenizer=custom_tokenizer
)
trainer.train()
# Out:
# /Users/waterondaway/Laboratory/medicine-scan-lm/.venv/lib/python3.10/site-packages/transformers/training_args.py:1594: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /var/folders/xc/h44mkk7s0hx2k11xb082y6l00000gn/T/ipykernel_939/3218068546.py:19: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='1601' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1601/2000 1:42:29 < 25:34, 0.26 it/s, Epoch 8/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.548200</td>
#       <td>0.415683</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.369500</td>
#       <td>0.292850</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.273300</td>
#       <td>0.214964</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.195500</td>
#       <td>0.172715</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.141200</td>
#       <td>0.134123</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.118000</td>
#       <td>0.161079</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.084200</td>
#       <td>0.105103</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.058400</td>
#       <td>0.095312</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Laboratory/medicine-scan-lm/.venv/lib/python3.10/site-packages/torch/serialization.py:944, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     943 with _open_zipfile_writer(f) as opened_zipfile:
# --> 944     _save(
#     945         obj,
#     946         opened_zipfile,
#     947         pickle_module,
#     948         pickle_protocol,
#     949         _disable_byteorder_record,
#     950     )
#     951     return
#
# File ~/Laboratory/medicine-scan-lm/.venv/lib/python3.10/site-packages/torch/serialization.py:1216, in _save(obj, zip_file, pickle_module, pickle_protocol, _disable_byteorder_record)
#    1215 # Now that it is on the CPU we can directly copy it into the zip file
# -> 1216 zip_file.write_record(name, storage, num_bytes)
#
# RuntimeError: [enforce fail at inline_container.cc:820] . PytorchStreamWriter failed writing file data/1: file write failed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 26
#       6 training_arguments = TrainingArguments(
#       7     output_dir='../output/model/custom_tokenizer',
#       8     num_train_epochs=10,
#    (...)
#      17     load_best_model_at_end=True
#      18 )
#      19 trainer = Trainer(
#      20     model=xlm_roberta_model,
#      21     args=training_arguments,
#    (...)
#      24     tokenizer=custom_tokenizer
#      25 )
# ---> 26 trainer.train()
#
# File ~/Laboratory/medicine-scan-lm/.venv/lib/python3.10/site-packages/transformers/trainer.py:2241, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2239         hf_hub_utils.enable_progress_bars()
#    2240 else:
# -> 2241     return inner_training_loop(
#    2242         args=args,
#    2243         resume_from_checkpoint=resume_from_checkpoint,
#    2244         trial=trial,
#    2245         ignore_keys_for_eval=ignore_keys_for_eval,
#    2246     )
#
# File ~/Laboratory/medicine-scan-lm/.venv/lib/python3.10/site-packages/transformers/trainer.py:2639, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2636     self.control.should_training_stop = True
#    2638 self.control = self.callback_handler.on_epoch_end(args, self.state, self.control)
# -> 2639 self._maybe_log_save_evaluate(tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time)
#    2641 if DebugOption.TPU_METRICS_DEBUG in self.args.debug:
#    2642     if is_torch_xla_available():
#    2643         # tpu-comment: Logging debug metrics for PyTorch/XLA (compile, execute times, ops, etc.)
#
# File ~/Laboratory/medicine-scan-lm/.venv/lib/python3.10/site-packages/transformers/trainer.py:3092, in Trainer._maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time)
#    3089         self.control.should_save = is_new_best_metric
#    3091 if self.control.should_save:
# -> 3092     self._save_checkpoint(model, trial)
#    3093     self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#
# File ~/Laboratory/medicine-scan-lm/.venv/lib/python3.10/site-packages/transformers/trainer.py:3194, in Trainer._save_checkpoint(self, model, trial)
#    3190 self.save_model(output_dir, _internal_call=True)
#    3192 if not self.args.save_only_model:
#    3193     # Save optimizer and scheduler
# -> 3194     self._save_optimizer_and_scheduler(output_dir)
#    3195     self._save_scaler(output_dir)
#    3196     # Save RNG state
#
# File ~/Laboratory/medicine-scan-lm/.venv/lib/python3.10/site-packages/transformers/trainer.py:3316, in Trainer._save_optimizer_and_scheduler(self, output_dir)
#    3311     save_fsdp_optimizer(
#    3312         self.accelerator.state.fsdp_plugin, self.accelerator, self.optimizer, self.model, output_dir
#    3313     )
#    3314 elif self.args.should_save:
#    3315     # deepspeed.save_checkpoint above saves model/optim/sched
# -> 3316     torch.save(self.optimizer.state_dict(), os.path.join(output_dir, OPTIMIZER_NAME))
#    3318 # Save SCHEDULER & SCALER
#    3319 is_deepspeed_custom_scheduler = self.is_deepspeed_enabled and not isinstance(
#    3320     self.lr_scheduler, DeepSpeedSchedulerWrapper
#    3321 )
#
# File ~/Laboratory/medicine-scan-lm/.venv/lib/python3.10/site-packages/torch/serialization.py:943, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     940 _check_save_filelike(f)
#     942 if _use_new_zipfile_serialization:
# --> 943     with _open_zipfile_writer(f) as opened_zipfile:
#     944         _save(
#     945             obj,
#     946             opened_zipfile,
#    (...)
#     949             _disable_byteorder_record,
#     950         )
#     951         return
#
# File ~/Laboratory/medicine-scan-lm/.venv/lib/python3.10/site-packages/torch/serialization.py:784, in _open_zipfile_writer_file.__exit__(self, *args)
#     783 def __exit__(self, *args) -> None:
# --> 784     self.file_like.write_end_of_file()
#     785     if self.file_stream is not None:
#     786         self.file_stream.close()
#
# RuntimeError: [enforce fail at inline_container.cc:626] . unexpected pos 46016 vs 45908

# %%
# ใช้โมเดลและ tokenizer จาก trainer โดยตรง
model = trainer.model
tokenizer = trainer.tokenizer
# Out:
# Trainer.tokenizer is now deprecated. You should use Trainer.processing_class instead.

# %%
print(model.config.id2label)
# Out:
# {0: 'O', 1: 'B-DRUG_NAME', 2: 'I-DRUG_NAME', 3: 'B-DOSAGE', 4: 'I-DOSAGE', 5: 'B-FORM', 6: 'I-FORM', 7: 'B-WARNINGS', 8: 'I-WARNINGS', 9: 'B-INDICATIONS', 10: 'I-INDICATIONS', 11: 'B-USAGE_INSTRUCTIONS', 12: 'I-USAGE_INSTRUCTIONS'}

# %%
from transformers import pipeline

# สร้าง NER pipeline
ner_pipeline = pipeline("ner", model='../output/model/custom_tokenizer/v1', tokenizer='../output/model/custom_tokenizer/v1', aggregation_strategy="simple")

# ทดสอบทำนาย
text = "ธนภณ พรสีมา"
ner_results = ner_pipeline(text)
print(ner_results)

for entity in ner_results:
    print(f"{entity['word']} ({entity['entity_group']}): {entity['score']:.3f}")
# Out:
# Device set to use mps:0
# [{'entity_group': 'WARNINGS', 'score': 0.7540153, 'word': '-10-', 'start': 34, 'end': 38}, {'entity_group': 'WARNINGS', 'score': 0.42050874, 'word': '15 20', 'start': 38, 'end': 43}, {'entity_group': 'INDICATIONS', 'score': 0.5669694, 'word': '26-08-18 ควร', 'start': 43, 'end': 55}, {'entity_group': 'USAGE_INSTRUCTIONS', 'score': 0.9595935, 'word': 'ใช้ตามคําแนะนําของแพทย์ ลดไข้ในผู้ป่วยไข้สูง เข', 'start': 55, 'end': 100}, {'entity_group': 'INDICATIONS', 'score': 0.8521242, 'word': 'ย่าขวดให้เข้ากันก่อนทุกครั้ง', 'start': 100, 'end': 128}]
# -10- (WARNINGS): 0.754
# 15 20 (WARNINGS): 0.421
# 26-08-18 ควร (INDICATIONS): 0.567
# ใช้ตามคําแนะนําของแพทย์ ลดไข้ในผู้ป่วยไข้สูง เข (USAGE_INSTRUCTIONS): 0.960
# ย่าขวดให้เข้ากันก่อนทุกครั้ง (INDICATIONS): 0.852
