# %% [markdown]
# ## 💬 Test Fine-Tuning Language Model

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline
pipe = pipeline("token-classification", model="waterondaway/xlm-roberta-base")
# Out:
# Device set to use mps:0

# %%
from collections import defaultdict

text = "500 mg กินทุกเช้าวันละ 1 เม็ด ระวังไม่ให้กินเกินขนาดที่กำหนดช่วยปะวังอาการข้างเคียง"
results = pipe(text)
entities = defaultdict(str)
for result in results:
    tag = result['entity'].replace('B-', '').replace('I-', '')
    if result['score'] > 0.7:
        entities[tag] += result['word'].replace('▁', '')
entities = dict(entities)
print(entities)
# Out:
# {'DOSAGE': '500mg', 'USAGE_INSTRUCTIONS': 'กินทุกเช้าวันละ1เม็ด', 'WARNINGS': 'ระวังไม่ให้กินเกินขนาดที่กําหนด', 'INDICATIONS': 'ช่วยปะวังอาการข้างเคียง'}
